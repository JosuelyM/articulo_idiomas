# %%
from pylab import *
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

# %%
rutacon  = "/home/carlosp/investigacion/antiguos_proyectos/articulo_idiomas/Datos_art/Uso/Conjuntos/"

#orden idiomas
II1 = "EN"
II2 = "FR"
II3 = "GE"
II4 = "IT"
II5 = "SP"

e1_ab_a = II1 +"-"+ II2
e1_ac_a = II1 +"-"+ II3
e1_ad_a = II1 +"-"+ II4
e1_ae_a = II1 +"-"+ II5

e1_ab_b = II2 +"-"+ II1
e1_ac_b = II2 +"-"+ II3
e1_ad_b = II2 +"-"+ II4
e1_ae_b = II2 +"-"+ II5

e1_ab_c = II3 +"-"+ II1
e1_ac_c = II3 +"-"+ II2
e1_ad_c = II3 +"-"+ II4
e1_ae_c = II3 +"-"+ II5

e1_ab_d = II4 +"-"+ II1
e1_ac_d = II4 +"-"+ II2
e1_ad_d = II4 +"-"+ II3
e1_ae_d = II4 +"-"+ II5

e1_ab_e = II5 +"-"+ II1
e1_ac_e = II5 +"-"+ II2
e1_ad_e = II5 +"-"+ II3
e1_ae_e = II5 +"-"+ II4

#detalles esteticos del codigo
C1_EN = [0, 0.52, 0.67]
C2_EN = [0.78, 0.95, 1]

C1_FR = [1, 0.46, 0]
C2_FR = [1, 0.8, 0.36]

C1_GE = [0.53, 0, 0.7]
C2_GE = [0.91, 0.77, 0.95]

C1_IT = [0.19, 0.51, 0.02]
C2_IT = [0.58, 1, 0.53]

C1_SP = [0.64, 0, 0]
C2_SP = [1, 0.51, 0.38]

Yearst = arange(1900, 2007, 1)

# %%
#ab_a   uso del ingles en el frances  EN-FR
#ac_a   uso del ingles en el aleman   EN-GE
#ad_a   uso del ingles en el italiano EN-IT
#ae_a   uso del ingles en el español  EN-SP

#ab_b   FR-EN
#ac_b   FR-GE
#ad_b   FR-IT
#ae_b   FR-SP

#ab_c   GE-EN
#ac_c   GE-FR
#ad_c   GE-IT
#ae_c   GE-SP

#ab_d   IT-EN
#ac_d   IT-FR
#ad_d   IT-GE
#ae_d   IT-SP

#ab_e   SP-EN
#ac_e   SP-FR
#ad_e   SP-GE
#ae_e   SP-IT

USO_ab_a = load(rutacon+ 'USO_ab_a.npy')
USO_ac_a = load(rutacon+ 'USO_ac_a.npy')
USO_ad_a = load(rutacon+ 'USO_ad_a.npy')
USO_ae_a = load(rutacon+ 'USO_ae_a.npy')
USO_ab_b = load(rutacon+ 'USO_ab_b.npy')
USO_ac_b = load(rutacon+ 'USO_ac_b.npy')
USO_ad_b = load(rutacon+ 'USO_ad_b.npy')
USO_ae_b = load(rutacon+ 'USO_ae_b.npy')
USO_ab_c = load(rutacon+ 'USO_ab_c.npy')
USO_ac_c = load(rutacon+ 'USO_ac_c.npy')
USO_ad_c = load(rutacon+ 'USO_ad_c.npy')
USO_ae_c = load(rutacon+ 'USO_ae_c.npy')
USO_ab_d = load(rutacon+ 'USO_ab_d.npy')
USO_ac_d = load(rutacon+ 'USO_ac_d.npy')
USO_ad_d = load(rutacon+ 'USO_ad_d.npy')
USO_ae_d = load(rutacon+ 'USO_ae_d.npy')
USO_ab_e = load(rutacon+ 'USO_ab_e.npy')
USO_ac_e = load(rutacon+ 'USO_ac_e.npy')
USO_ad_e = load(rutacon+ 'USO_ad_e.npy')
USO_ae_e = load(rutacon+ 'USO_ae_e.npy')

# %%
USO_ae_e = load(rutacon+ 'USO_ae_e.npy')

# %%
#ab_a   uso del ingles en el frances  EN-FR
np.savetxt('Conjuntos/USO_aEN-FR.txt', USO_ab_a, delimiter=',')
#ac_a   uso del ingles en el aleman   EN-GE
np.savetxt('Conjuntos/USO_aEN-GE.txt', USO_ac_a, delimiter=',')
#ad_a   uso del ingles en el italiano EN-IT
np.savetxt('Conjuntos/USO_aEN-IT.txt', USO_ad_a, delimiter=',')
#ae_a   uso del ingles en el español  EN-SP
np.savetxt('Conjuntos/USO_aEN-SP.txt', USO_ae_a, delimiter=',')

#ab_b   FR-EN
np.savetxt('Conjuntos/USO_aFR-EN.txt', USO_ab_b, delimiter=',')
#ac_b   FR-GE
np.savetxt('Conjuntos/USO_aFR-GE.txt', USO_ac_b, delimiter=',')
#ad_b   FR-IT
np.savetxt('Conjuntos/USO_aFR-IT.txt', USO_ad_b, delimiter=',')
#ae_b   FR-SP
np.savetxt('Conjuntos/USO_aFR-SP.txt', USO_ae_b, delimiter=',')

#ab_c   GE-EN
np.savetxt('Conjuntos/USO_aGE-EN.txt', USO_ab_c, delimiter=',')
#ac_c   GE-FR
np.savetxt('Conjuntos/USO_aGE-FR.txt', USO_ac_c, delimiter=',')
#ad_c   GE-IT
np.savetxt('Conjuntos/USO_aGE-IT.txt', USO_ad_c, delimiter=',')
#ae_c   GE-SP
np.savetxt('Conjuntos/USO_aGE-SP.txt', USO_ae_c, delimiter=',')

#ab_d   IT-EN
np.savetxt('Conjuntos/USO_aIT-EN.txt', USO_ab_d, delimiter=',')
#ac_d   IT-FR
np.savetxt('Conjuntos/USO_aIT-FR.txt', USO_ac_d, delimiter=',')
#ad_d   IT-GE
np.savetxt('Conjuntos/USO_aIT-GE.txt', USO_ad_d, delimiter=',')
#ae_d   IT-SP
np.savetxt('Conjuntos/USO_aIT-SP.txt', USO_ae_d, delimiter=',')


#ab_e   SP-EN
np.savetxt('Conjuntos/USO_aSP-EN.txt', USO_ab_e, delimiter=',')
#ac_e   SP-FR
np.savetxt('Conjuntos/USO_aSP-FR.txt', USO_ac_e, delimiter=',')
#ad_e   SP-GE
np.savetxt('Conjuntos/USO_aSP-GE.txt', USO_ad_e, delimiter=',')
#ae_e   SP-IT
np.savetxt('Conjuntos/USO_aSP-IT.txt', USO_ae_e, delimiter=',')

# %%
USO_ad_e
# Out:
# array([0.14765283, 0.14748971, 0.1510427 , 0.15181988, 0.14743146,
#        0.14149218, 0.13999732, 0.13661878, 0.12966232, 0.12325056,
#        0.12376762, 0.12484315, 0.11951651, 0.12059121, 0.11995463,
#        0.12021195, 0.11956698, 0.11765718, 0.11709569, 0.11630701,
#        0.11800327, 0.11649592, 0.11907423, 0.1192388 , 0.11798388,
#        0.11962045, 0.11985399, 0.1204488 , 0.11553899, 0.11419059,
#        0.1145482 , 0.11262159, 0.10885814, 0.10752316, 0.10614857,
#        0.10504319, 0.11959375, 0.11711355, 0.11855306, 0.12093061,
#        0.12204571, 0.12865262, 0.12114711, 0.12120604, 0.11833048,
#        0.12126617, 0.11928287, 0.11498624, 0.10807875, 0.10688869,
#        0.1097075 , 0.10519059, 0.10585691, 0.10972273, 0.10948005,
#        0.11472719, 0.1132706 , 0.11362035, 0.11917468, 0.11773446,
#        0.12176557, 0.12227604, 0.12823196, 0.13328072, 0.13026616,
#        0.13324197, 0.13587271, 0.13725893, 0.13931557, 0.14123828,
# ...

# %%
np.savetxt('Conjuntos/USO_ad_e.txt', USO_ad_e, delimiter=',')

# %%
EN_patch = mpatches.Patch(color = C1_EN, label = 'English')
FR_patch = mpatches.Patch(color = C1_FR, label = 'French')
GE_patch = mpatches.Patch(color = C1_GE, label = 'German')
IT_patch = mpatches.Patch(color = C1_IT, label = 'Italian')
SP_patch = mpatches.Patch(color = C1_SP, label = 'Spanish')

# %%
rcParams['figure.figsize'] = [20, 30]
fig = plt.figure()

ax1 = plt.subplot2grid(shape=(6,2), loc=(0,0))
ax2 = plt.subplot2grid(shape=(6,2), loc=(0,1))
ax3 = plt.subplot2grid(shape=(6,2), loc=(1,0))
ax4 = plt.subplot2grid(shape=(6,2), loc=(1,1))
ax5 = plt.subplot2grid(shape=(6,2), loc=(2,0))
ax6 = plt.subplot2grid(shape=(6,2), loc=(2,1))


ax1.plot(Yearst, USO_ab_a/mean(USO_ab_a), color = C1_FR, label = 'x ' + str(round(mean(USO_ab_a)*10,2)))
ax1.plot(Yearst, USO_ac_a/mean(USO_ac_a), color = C1_GE, label = 'x ' + str(round(mean(USO_ac_a)*10,2)))
ax1.plot(Yearst, USO_ad_a/mean(USO_ad_a), color = C1_IT, label = 'x ' + str(round(mean(USO_ad_a)*10,2)))
ax1.plot(Yearst, USO_ae_a/mean(USO_ae_a), color = C1_SP, label = 'x ' + str(round(mean(USO_ae_a)*10,2)))
ax1.set_xlim(1900, 2006)
ax1.set_ylim(0.5, 1.5)
ax1.set_xlabel(r'Years', fontsize= 23)
ax1.set_ylabel(r'$U_{\,x\,10^{-3}}$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax1.set_xticks(arange(1900, 2010, 10) )
ax1.xaxis.set_tick_params(rotation=45)
ax1.text(1903, 1.4, r'English',fontsize=20)
ax1.legend(loc=4, ncol=2, frameon=False, handlelength=0.5)

ax2.plot(Yearst, USO_ab_b/mean(USO_ab_b), color = C1_EN, label = 'x ' + str(round(mean(USO_ab_b)*10,2)))
ax2.plot(Yearst, USO_ac_b/mean(USO_ac_b), color = C1_GE, label = 'x ' + str(round(mean(USO_ac_b)*10,2)))
ax2.plot(Yearst, USO_ad_b/mean(USO_ad_b), color = C1_IT, label = 'x ' + str(round(mean(USO_ad_b)*10,2)))
ax2.plot(Yearst, USO_ae_b/mean(USO_ae_b), color = C1_SP, label = 'x ' + str(round(mean(USO_ae_b)*10,2)))
ax2.set_xlim(1900, 2006)
ax2.set_ylim(0.5, 1.5)
ax2.set_xlabel(r'Years', fontsize= 23)
#ax2.set_ylabel(r'$U_{\,x\,10^{-3}}$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax2.set_xticks(arange(1900, 2010, 10) )
ax2.xaxis.set_tick_params(rotation=45)
ax2.text(1903, 1.4, r'French',fontsize=20)
ax2.legend(loc=4, ncol=2, frameon=False, handlelength=0.5)

ax3.plot(Yearst, USO_ab_c/mean(USO_ab_c), color = C1_EN, label = 'x ' + str(round(mean(USO_ab_c)*10,2)))
ax3.plot(Yearst, USO_ac_c/mean(USO_ac_c), color = C1_FR, label = 'x ' + str(round(mean(USO_ac_c)*10,2)))
ax3.plot(Yearst, USO_ad_c/mean(USO_ad_c), color = C1_IT, label = 'x ' + str(round(mean(USO_ad_c)*10,2)))
ax3.plot(Yearst, USO_ae_c/mean(USO_ae_c), color = C1_SP, label = 'x ' + str(round(mean(USO_ae_c)*10,2)))
ax3.set_xlim(1900, 2006)
ax3.set_ylim(0.2, 1.9)
ax3.set_xlabel(r'Years', fontsize= 23)
ax3.set_ylabel(r'$U_{\,x\,10^{-3}}$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax3.set_xticks(arange(1900, 2010, 10) )
ax3.xaxis.set_tick_params(rotation=45)
ax3.text(1903, 1.7, r'German',fontsize=20)
ax3.legend(loc=4, ncol=2, frameon=False, handlelength=0.5)

ax4.plot(Yearst, USO_ab_d/mean(USO_ab_d), color = C1_EN, label = 'x ' + str(round(mean(USO_ab_d)*10,2)))
ax4.plot(Yearst, USO_ac_d/mean(USO_ac_d), color = C1_FR, label = 'x ' + str(round(mean(USO_ac_d)*10,2)))
ax4.plot(Yearst, USO_ad_d/mean(USO_ad_d), color = C1_GE, label = 'x ' + str(round(mean(USO_ad_d)*10,2)))
ax4.plot(Yearst, USO_ae_d/mean(USO_ae_d), color = C1_SP, label = 'x ' + str(round(mean(USO_ae_d)*10,2)))
ax4.set_xlim(1900, 2006)
ax4.set_ylim(0.6, 1.5)
ax4.set_xlabel(r'Years', fontsize= 23)
#ax4.set_ylabel(r'$U_{\,x\,10^{-3}}$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax4.set_xticks(arange(1900, 2010, 10) )
ax4.xaxis.set_tick_params(rotation=45)
ax4.text(1903, 1.4, r'Italian',fontsize=20)
ax4.legend(loc=4, ncol=2, frameon=False, handlelength=0.5)

ax5.plot(Yearst, USO_ab_e/mean(USO_ab_e), color = C1_EN, label = 'x ' + str(round(mean(USO_ab_e)*10,2)))
ax5.plot(Yearst, USO_ac_e/mean(USO_ac_e), color = C1_FR, label = 'x ' + str(round(mean(USO_ac_e)*10,2)))
ax5.plot(Yearst, USO_ad_e/mean(USO_ad_e), color = C1_GE, label = 'x ' + str(round(mean(USO_ad_e)*10,2)))
ax5.plot(Yearst, USO_ae_e/mean(USO_ae_e), color = C1_IT, label = 'x ' + str(round(mean(USO_ae_e)*10,2)))
ax5.set_xlim(1900, 2006)
ax5.set_ylim(0.7, 1.35)
ax5.set_xlabel(r'Years', fontsize= 23)
ax5.set_ylabel(r'$U_{\,x\,10^{-3}}$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax5.set_xticks(arange(1900, 2010, 10) )
ax5.xaxis.set_tick_params(rotation=45)
ax5.text(1903, 1.28, r'Spanish',fontsize=20)
ax5.legend(loc=4, ncol=2, frameon=False, handlelength=0.5)


ax6.legend(handles=[EN_patch, FR_patch, GE_patch, IT_patch, SP_patch],
           loc='best', 
           bbox_to_anchor =(0.2, 0.9, 0.1, 0.1), #Position of legend, x0, y0, width, height
           borderaxespad = 0.8,     # Small spacing around legend box
           title= r'Legends',     # Title for the legend
           fontsize=23
          )

ax6.axis('off')
plt.tight_layout()

#fig.savefig('USO_OR.png', bbox_inches = 'tight')
