# %%
from pylab import *

# %%
ruta1 = "/home/carlosp/investigacion/antiguos_proyectos/articulo_idiomas/Datos_art/Zipf/conjuntos/"
ruta2 = "/home/carlosp/investigacion/antiguos_proyectos/articulo_idiomas/Datos_art/Zipf/graficas/"

etiqueta1 = "_a.npy"
etiqueta2 = "_b.npy"
etiqueta3 = "_c.npy"
etiqueta4 = "_d.npy"
etiqueta5 = "_e.npy"

e1 = "EN"
e2 = "FR"
e3 = "GE"
e4 = "IT"
e5 = "SP"

e_ab_a = e1 + '-' + e2
e_ac_a = e1 + '-' + e3
e_ad_a = e1 + '-' + e4
e_ae_a = e1 + '-' + e5

e_ab_b = e2 + '-' + e1
e_ac_b = e2 + '-' + e3
e_ad_b = e2 + '-' + e4
e_ae_b = e2 + '-' + e5

e_ab_c = e3 + '-' + e1
e_ac_c = e3 + '-' + e2
e_ad_c = e3 + '-' + e4
e_ae_c = e3 + '-' + e5

e_ab_d = e4 + '-' + e1
e_ac_d = e4 + '-' + e2
e_ad_d = e4 + '-' + e3
e_ae_d = e4 + '-' + e5

e_ab_e = e5 + '-' + e1
e_ac_e = e5 + '-' + e2
e_ad_e = e5 + '-' + e3
e_ae_e = e5 + '-' + e4

C1_EN = [0, 0.52, 0.67]
C2_EN = [0.470, 0.733, 0.807]

C1_FR = [1, 0.46, 0]
C2_FR = [1, 0.8, 0.36]

C1_GE = [0.53, 0, 0.7]
C2_GE = [0.541, 0.541, 0.717]

C1_IT = [0.19, 0.51, 0.02]
C2_IT = [0.384, 0.662, 0.239]

C1_SP = [0.64, 0, 0]
C2_SP = [1, 0.160, 0.160]

# %%
ruta1 + 'ZL_A.npy'
# Out:
# '/home/carlosp/investigacion/antiguos_proyectos/articulo_idiomas/Datos_art/Zipf/conjuntos/ZL_A.npy'

# %%
ZL_A = load(ruta1 + 'ZL_A.npy', allow_pickle=True).tolist()
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py:438, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     437 try:
# --> 438     return pickle.load(fid, **pickle_kwargs)
#     439 except Exception as e:
#
# UnpicklingError: invalid load key, 'v'.
#
# The above exception was the direct cause of the following exception:
#
# UnpicklingError                           Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 ZL_A = load(ruta1 + 'ZL_A.npy', allow_pickle=True).tolist()
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py:440, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     438     return pickle.load(fid, **pickle_kwargs)
#     439 except Exception as e:
# --> 440     raise pickle.UnpicklingError(
# ...

# %%
ZL_A = load(ruta1 + 'ZL_A.npy').tolist()
ZL_B = load(ruta1 + 'ZL_B.npy').tolist()
ZL_C = load(ruta1 + 'ZL_C.npy').tolist()
ZL_D = load(ruta1 + 'ZL_D.npy').tolist()
ZL_E = load(ruta1 + 'ZL_E.npy').tolist()

##ZM[y1][0] = rango que tienen dentro del idioma a donde migran, para el año y1
##ZM[y1][1] = frecuencia

ZM_ab_a = load(ruta1 + 'ZM_ab' + etiqueta1).tolist()
ZM_ac_a = load(ruta1 + 'ZM_ac' + etiqueta1).tolist()
ZM_ad_a = load(ruta1 + 'ZM_ad' + etiqueta1).tolist()
ZM_ae_a = load(ruta1 + 'ZM_ae' + etiqueta1).tolist()

ZM_ab_b = load(ruta1 + 'ZM_ab' + etiqueta2).tolist()
ZM_ac_b = load(ruta1 + 'ZM_ac' + etiqueta2).tolist()
ZM_ad_b = load(ruta1 + 'ZM_ad' + etiqueta2).tolist()
ZM_ae_b = load(ruta1 + 'ZM_ae' + etiqueta2).tolist()

ZM_ab_c = load(ruta1 + 'ZM_ab' + etiqueta3).tolist()
ZM_ac_c = load(ruta1 + 'ZM_ac' + etiqueta3).tolist()
ZM_ad_c = load(ruta1 + 'ZM_ad' + etiqueta3).tolist()
ZM_ae_c = load(ruta1 + 'ZM_ae' + etiqueta3).tolist()

ZM_ab_d = load(ruta1 + 'ZM_ab' + etiqueta4).tolist()
ZM_ac_d = load(ruta1 + 'ZM_ac' + etiqueta4).tolist()
ZM_ad_d = load(ruta1 + 'ZM_ad' + etiqueta4).tolist()
ZM_ae_d = load(ruta1 + 'ZM_ae' + etiqueta4).tolist()

ZM_ab_e = load(ruta1 + 'ZM_ab' + etiqueta5).tolist()
ZM_ac_e = load(ruta1 + 'ZM_ac' + etiqueta5).tolist()
ZM_ad_e = load(ruta1 + 'ZM_ad' + etiqueta5).tolist()
ZM_ae_e = load(ruta1 + 'ZM_ae' + etiqueta5).tolist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 ZL_A = load(ruta1 + 'ZL_A.npy').tolist()
#       2 ZL_B = load(ruta1 + 'ZL_B.npy').tolist()
#       3 ZL_C = load(ruta1 + 'ZL_C.npy').tolist()
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/npyio.py:435, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     432 else:
#     433     # Try a pickle
#     434     if not allow_pickle:
# --> 435         raise ValueError("Cannot load file containing pickled data "
#     436                          "when allow_pickle=False")
#     437     try:
#     438         return pickle.load(fid, **pickle_kwargs)
#
# ValueError: Cannot load file containing pickled data when allow_pickle=False

# %%
rcParams['figure.figsize'] = [18, 7]
rcParams['font.size'] = 18
rcParams['axes.labelsize'] = 18

# %%
Y1 = 1950
indice = Y1-1740

rcParams['figure.figsize'] = [15, 15]
fig = plt.figure()

ax1  = plt.subplot2grid(shape=(3,4), loc=(0,0), colspan=2)
ax2  = plt.subplot2grid(shape=(3,4), loc=(0,2), colspan=2)
ax3  = plt.subplot2grid(shape=(3,4), loc=(1,0), colspan=2)
ax4  = plt.subplot2grid(shape=(3,4), loc=(1,2), colspan=2)
ax5  = plt.subplot2grid(shape=(3,4), loc=(2,1), colspan=2)

ax1.plot(ZL_A[indice][0], ZL_A[indice][1],           color = C1_EN, label = e1)
ax1.plot(ZM_ab_b[indice][0],ZM_ab_b[indice][1], 'o', color = C1_FR, label = e2)
ax1.plot(ZM_ab_c[indice][0],ZM_ab_c[indice][1], 'o', color = C1_GE, label = e3)
ax1.plot(ZM_ab_d[indice][0],ZM_ab_d[indice][1], 'o', color = C1_IT, label = e4)
ax1.plot(ZM_ab_e[indice][0],ZM_ab_e[indice][1], 'o', color = C1_SP, label = e5)
ax1.set_xscale('log')
ax1.set_yscale('log')
#ax1.axis('equal')
ax1.set_ylabel(r'$f\,(k)$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax1.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax2.plot(ZL_B[indice][0], ZL_B[indice][1],           color = C1_FR, label = e2)
ax2.plot(ZM_ab_a[indice][0],ZM_ab_a[indice][1], 'o', color = C1_EN, label = e1)
ax2.plot(ZM_ac_c[indice][0],ZM_ac_c[indice][1], 'o', color = C1_GE, label = e3)
ax2.plot(ZM_ac_d[indice][0],ZM_ac_d[indice][1], 'o', color = C1_IT, label = e4)
ax2.plot(ZM_ac_e[indice][0],ZM_ac_e[indice][1], 'o', color = C1_SP, label = e5)
ax2.set_xscale('log')
ax2.set_yscale('log')
#ax2.axis('equal')
ax2.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax3.plot(ZL_C[indice][0], ZL_C[indice][1],           color = C1_GE, label = e3)
ax3.plot(ZM_ac_a[indice][0],ZM_ac_a[indice][1], 'o', color = C1_EN, label = e1)
ax3.plot(ZM_ac_b[indice][0],ZM_ac_b[indice][1], 'o', color = C1_FR, label = e2)
ax3.plot(ZM_ad_d[indice][0],ZM_ad_d[indice][1], 'o', color = C1_IT, label = e4)
ax3.plot(ZM_ad_e[indice][0],ZM_ad_e[indice][1], 'o', color = C1_SP, label = e5)
ax3.set_xscale('log')
ax3.set_yscale('log')
#ax3.axis('equal')
ax3.set_ylabel(r'$f\,(k)$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax3.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax4.plot(ZL_D[indice][0], ZL_D[indice][1],           color = C1_IT, label = e4)
ax4.plot(ZM_ad_a[indice][0],ZM_ad_a[indice][1], 'o', color = C1_EN, label = e2)
ax4.plot(ZM_ad_b[indice][0],ZM_ad_b[indice][1], 'o', color = C1_FR, label = e2)
ax4.plot(ZM_ad_c[indice][0],ZM_ad_c[indice][1], 'o', color = C1_GE, label = e3)
ax4.plot(ZM_ae_e[indice][0],ZM_ae_e[indice][1], 'o', color = C1_SP, label = e5)
ax4.set_xscale('log')
ax4.set_yscale('log')
#ax4.axis('equal')
ax4.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax5.plot(ZL_E[indice][0], ZL_E[indice][1],           color = C1_SP, label = e5)
ax5.plot(ZM_ae_a[indice][0],ZM_ae_a[indice][1], 'o', color = C1_EN, label = e1)
ax5.plot(ZM_ae_b[indice][0],ZM_ae_b[indice][1], 'o', color = C1_FR, label = e2)
ax5.plot(ZM_ae_c[indice][0],ZM_ae_c[indice][1], 'o', color = C1_GE, label = e3)
ax5.plot(ZM_ae_d[indice][0],ZM_ae_d[indice][1], 'o', color = C1_IT, label = e4)
ax5.set_xscale('log')
ax5.set_yscale('log')
#ax5.axis('equal')
ax5.set_ylabel(r'$f\,(k)$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax5.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

plt.tight_layout()

#fig.savefig(ruta2 +'ZL_todos.png', bbox_inches = 'tight')

# %%
fig = plt.figure()

ax1  = plt.subplot2grid(shape=(3,4), loc=(0,0), colspan=2)
ax2  = plt.subplot2grid(shape=(3,4), loc=(0,2), colspan=2)
ax3  = plt.subplot2grid(shape=(3,4), loc=(1,0), colspan=2)
ax4  = plt.subplot2grid(shape=(3,4), loc=(1,2), colspan=2)
ax5  = plt.subplot2grid(shape=(3,4), loc=(2,1), colspan=2)

ax1.plot(arange(1, len(ZM_ab_b[indice][1])+1), array(ZM_ab_b[indice][1])/ ZM_ab_b[indice][1][0], color = C1_FR, label = e_ab_b)
ax1.plot(arange(1, len(ZM_ab_c[indice][1])+1), array(ZM_ab_c[indice][1])/ ZM_ab_c[indice][1][0], color = C1_GE, label = e_ab_c)
ax1.plot(arange(1, len(ZM_ab_d[indice][1])+1), array(ZM_ab_d[indice][1])/ ZM_ab_d[indice][1][0], color = C1_IT, label = e_ab_d)
ax1.plot(arange(1, len(ZM_ab_e[indice][1])+1), array(ZM_ab_e[indice][1])/ ZM_ab_e[indice][1][0], color = C1_SP, label = e_ab_e)
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_ylabel(r'$f\,(k)$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax1.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax2.plot(arange(1, len(ZM_ab_a[indice][1])+1), array(ZM_ab_a[indice][1])/ ZM_ab_a[indice][1][0], color = C1_EN, label = e_ab_a)
ax2.plot(arange(1, len(ZM_ac_c[indice][1])+1), array(ZM_ac_c[indice][1])/ ZM_ac_c[indice][1][0], color = C1_GE, label = e_ac_c)
ax2.plot(arange(1, len(ZM_ac_d[indice][1])+1), array(ZM_ac_d[indice][1])/ ZM_ac_d[indice][1][0], color = C1_IT, label = e_ac_d)
ax2.plot(arange(1, len(ZM_ac_e[indice][1])+1), array(ZM_ac_e[indice][1])/ ZM_ac_e[indice][1][0], color = C1_SP, label = e_ac_e)
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax3.plot(arange(1, len(ZM_ac_a[indice][1])+1), array(ZM_ac_a[indice][1])/ ZM_ac_a[indice][1][0], color = C1_EN, label = e_ac_a)
ax3.plot(arange(1, len(ZM_ac_b[indice][1])+1), array(ZM_ac_b[indice][1])/ ZM_ac_b[indice][1][0], color = C1_FR, label = e_ac_b)
ax3.plot(arange(1, len(ZM_ad_d[indice][1])+1), array(ZM_ad_d[indice][1])/ ZM_ad_d[indice][1][0], color = C1_IT, label = e_ad_d)
ax3.plot(arange(1, len(ZM_ad_e[indice][1])+1), array(ZM_ad_e[indice][1])/ ZM_ad_e[indice][1][0], color = C1_SP, label = e_ad_e)
ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_ylabel(r'$f\,(k)$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax3.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax4.plot(arange(1, len(ZM_ad_a[indice][1])+1), array(ZM_ad_a[indice][1])/ ZM_ad_a[indice][1][0], color = C1_EN, label = e_ad_a)
ax4.plot(arange(1, len(ZM_ad_b[indice][1])+1), array(ZM_ad_b[indice][1])/ ZM_ad_b[indice][1][0], color = C1_FR, label = e_ad_b)
ax4.plot(arange(1, len(ZM_ad_c[indice][1])+1), array(ZM_ad_c[indice][1])/ ZM_ad_c[indice][1][0], color = C1_GE, label = e_ad_c)
ax4.plot(arange(1, len(ZM_ae_e[indice][1])+1), array(ZM_ae_e[indice][1])/ ZM_ae_e[indice][1][0], color = C1_SP, label = e_ae_e)
ax4.set_xscale('log')
ax4.set_yscale('log')
ax4.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax5.plot(arange(1, len(ZM_ae_a[indice][1])+1), array(ZM_ae_a[indice][1])/ ZM_ae_a[indice][1][0], color = C1_EN, label = e_ae_a)
ax5.plot(arange(1, len(ZM_ae_b[indice][1])+1), array(ZM_ae_b[indice][1])/ ZM_ae_b[indice][1][0], color = C1_FR, label = e_ae_b)
ax5.plot(arange(1, len(ZM_ae_c[indice][1])+1), array(ZM_ae_c[indice][1])/ ZM_ae_c[indice][1][0], color = C1_GE, label = e_ae_c)
ax5.plot(arange(1, len(ZM_ae_d[indice][1])+1), array(ZM_ae_d[indice][1])/ ZM_ae_d[indice][1][0], color = C1_IT, label = e_ae_d)
ax5.set_xscale('log')
ax5.set_yscale('log')
ax5.set_ylabel(r'$f\,(k)$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax5.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

plt.tight_layout()

#fig.savefig(ruta2 +'ZL_receptor.png', bbox_inches = 'tight')

# %%
fig = plt.figure()

ax1  = plt.subplot2grid(shape=(3,4), loc=(0,0), colspan=2)
ax2  = plt.subplot2grid(shape=(3,4), loc=(0,2), colspan=2)
ax3  = plt.subplot2grid(shape=(3,4), loc=(1,0), colspan=2)
ax4  = plt.subplot2grid(shape=(3,4), loc=(1,2), colspan=2)
ax5  = plt.subplot2grid(shape=(3,4), loc=(2,1), colspan=2)

ax1.plot(arange(1, len(ZM_ab_a[indice][1])+1), array(ZM_ab_a[indice][1])/ ZM_ab_a[indice][1][0], color = C1_FR, label = e_ab_a)
ax1.plot(arange(1, len(ZM_ac_a[indice][1])+1), array(ZM_ac_a[indice][1])/ ZM_ac_a[indice][1][0], color = C1_GE, label = e_ac_a)
ax1.plot(arange(1, len(ZM_ad_a[indice][1])+1), array(ZM_ad_a[indice][1])/ ZM_ad_a[indice][1][0], color = C1_IT, label = e_ad_a)
ax1.plot(arange(1, len(ZM_ae_a[indice][1])+1), array(ZM_ae_a[indice][1])/ ZM_ae_a[indice][1][0], color = C1_SP, label = e_ae_a)
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_ylabel(r'$f\,(k)$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax1.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax2.plot(arange(1, len(ZM_ab_b[indice][1])+1), array(ZM_ab_b[indice][1])/ ZM_ab_b[indice][1][0], color = C1_EN, label = e_ab_b)
ax2.plot(arange(1, len(ZM_ac_b[indice][1])+1), array(ZM_ac_b[indice][1])/ ZM_ac_b[indice][1][0], color = C1_GE, label = e_ac_b)
ax2.plot(arange(1, len(ZM_ad_b[indice][1])+1), array(ZM_ad_b[indice][1])/ ZM_ad_b[indice][1][0], color = C1_IT, label = e_ad_b)
ax2.plot(arange(1, len(ZM_ae_b[indice][1])+1), array(ZM_ae_b[indice][1])/ ZM_ae_b[indice][1][0], color = C1_SP, label = e_ae_b)
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax3.plot(arange(1, len(ZM_ab_c[indice][1])+1), array(ZM_ab_c[indice][1])/ ZM_ab_c[indice][1][0], color = C1_EN, label = e_ab_c)
ax3.plot(arange(1, len(ZM_ac_c[indice][1])+1), array(ZM_ac_c[indice][1])/ ZM_ac_c[indice][1][0], color = C1_FR, label = e_ac_c)
ax3.plot(arange(1, len(ZM_ad_c[indice][1])+1), array(ZM_ad_c[indice][1])/ ZM_ad_c[indice][1][0], color = C1_IT, label = e_ad_c)
ax3.plot(arange(1, len(ZM_ae_c[indice][1])+1), array(ZM_ae_c[indice][1])/ ZM_ae_c[indice][1][0], color = C1_SP, label = e_ae_c)
ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_ylabel(r'$f\,(k)$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax3.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax4.plot(arange(1, len(ZM_ab_d[indice][1])+1), array(ZM_ab_d[indice][1])/ ZM_ab_d[indice][1][0], color = C1_EN, label = e_ab_d)
ax4.plot(arange(1, len(ZM_ac_d[indice][1])+1), array(ZM_ac_d[indice][1])/ ZM_ac_d[indice][1][0], color = C1_FR, label = e_ac_d)
ax4.plot(arange(1, len(ZM_ad_d[indice][1])+1), array(ZM_ad_d[indice][1])/ ZM_ad_d[indice][1][0], color = C1_GE, label = e_ad_d)
ax4.plot(arange(1, len(ZM_ae_d[indice][1])+1), array(ZM_ae_d[indice][1])/ ZM_ae_d[indice][1][0], color = C1_SP, label = e_ae_d)
ax4.set_xscale('log')
ax4.set_yscale('log')
ax4.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

ax5.plot(arange(1, len(ZM_ab_e[indice][1])+1), array(ZM_ab_e[indice][1])/ ZM_ab_e[indice][1][0], color = C1_EN, label = e_ab_e)
ax5.plot(arange(1, len(ZM_ac_e[indice][1])+1), array(ZM_ac_e[indice][1])/ ZM_ac_e[indice][1][0], color = C1_FR, label = e_ac_e)
ax5.plot(arange(1, len(ZM_ad_e[indice][1])+1), array(ZM_ad_e[indice][1])/ ZM_ad_e[indice][1][0], color = C1_GE, label = e_ad_e)
ax5.plot(arange(1, len(ZM_ae_e[indice][1])+1), array(ZM_ae_e[indice][1])/ ZM_ae_e[indice][1][0], color = C1_IT, label = e_ae_e)
ax5.set_xscale('log')
ax5.set_yscale('log')
ax5.set_ylabel(r'$f\,(k)$', rotation=90, fontsize= 23, fontweight = "bold", position=(0.9,0.53))
ax5.legend(loc=0, ncol=2, frameon=False, handlelength=0.5)

plt.tight_layout()

#fig.savefig(ruta2 +'ZL_origen.png', bbox_inches = 'tight')
