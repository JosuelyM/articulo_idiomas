# %%
from pylab import *
from scipy.interpolate import splev, splrep
from scipy.stats import norm

# %%
rutacon  = "Conjuntos_barras/"
L1    = str('EN')
L2    = str('FR')
L3    = str('GE')
L4    = str('IT')
L5    = str('SP')

#detalles esteticos del codigo
C1_EN = [0, 0.52, 0.67]
C2_EN = [0.78, 0.95, 1]

C1_FR = [1, 0.46, 0]
C2_FR = [1, 0.8, 0.36]

C1_GE = [0.53, 0, 0.7]
C2_GE = [0.91, 0.77, 0.95]

C1_IT = [0.19, 0.51, 0.02]
C2_IT = [0.58, 1, 0.53]

C1_SP = [0.64, 0, 0]
C2_SP = [1, 0.51, 0.38]

# %%
#DBO ~ Datos Barra Origen.     Total de palabras nuevas del idioma origen en los demás
#DBR ~ Datos Barra Receptor.   Total de palabras de los demás idiomas en un idioma receptor
#PUO ~ Palabras Unicas Origen. Palabras unicas del idioma origen en todos los receptores

DBO_a = load(rutacon+ 'DBO_EN.npy',  allow_pickle=True)
DBO_b = load(rutacon+ 'DBO_FR.npy',  allow_pickle=True)
DBO_c = load(rutacon+ 'DBO_GE.npy',  allow_pickle=True)
DBO_d = load(rutacon+ 'DBO_IT.npy',  allow_pickle=True)
DBO_e = load(rutacon+ 'DBO_SP.npy',  allow_pickle=True)

DBR_a = load(rutacon+ 'DBR_EN.npy',  allow_pickle=True)
DBR_b = load(rutacon+ 'DBR_FR.npy',  allow_pickle=True)
DBR_c = load(rutacon+ 'DBR_GE.npy',  allow_pickle=True)
DBR_d = load(rutacon+ 'DBR_IT.npy',  allow_pickle=True)
DBR_e = load(rutacon+ 'DBR_SP.npy',  allow_pickle=True)

PUO_a = load(rutacon+ 'PUO_EN.npy',  allow_pickle=True)
PUO_b = load(rutacon+ 'PUO_FR.npy',  allow_pickle=True)
PUO_c = load(rutacon+ 'PUO_GE.npy',  allow_pickle=True)
PUO_d = load(rutacon+ 'PUO_IT.npy',  allow_pickle=True)
PUO_e = load(rutacon+ 'PUO_SP.npy',  allow_pickle=True)

# %%
rcParams['figure.figsize'] = [35, 10]
rcParams['font.size'] = 15
rcParams['axes.labelsize'] = 15
opacity   = 1
bar_width1 = 5
Ybar = arange(1900, 2010, 10)

# %%
CEN = bar(Ybar, (-1)*DBO_b[0], color = C1_EN, edgecolor='black')[0]
CFR = bar(Ybar, DBR_a[0], bar_width1, color = C1_FR,  edgecolor='black')[0]
CGE = bar(Ybar, DBR_a[1], bar_width1, color = C1_GE,  bottom=DBR_a[0], edgecolor='black')[0]
CIT = bar(Ybar, DBR_a[2], bar_width1, color = C1_IT,  bottom=DBR_a[0]+DBR_a[1], edgecolor='black')[0]
CSP = bar(Ybar, DBR_a[3], bar_width1, color = C1_SP,  bottom=DBR_a[0]+DBR_a[1]+DBR_a[2], edgecolor='black')[0]
CIO = plot(Ybar, array(PUO_a[2]), color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)[0]

# %%
fig = plt.figure(figsize = [25,10])

ax1 = plt.subplot2grid(shape=(2,6), loc=(0,0))
ax2 = plt.subplot2grid(shape=(2,6), loc=(0,1))
ax3 = plt.subplot2grid(shape=(2,6), loc=(0,2))
ax4 = plt.subplot2grid(shape=(2,6), loc=(1,0))
ax5 = plt.subplot2grid(shape=(2,6), loc=(1,1))
ax6 = plt.subplot2grid(shape=(2,6), loc=(1,2))

ax1.bar(Ybar, (-1)*DBO_b[0], color = C1_EN, edgecolor='black')[0]
ax1.bar(Ybar, DBR_a[0], bar_width1, color = C1_FR,  edgecolor='black')
ax1.bar(Ybar, DBR_a[1], bar_width1, color = C1_GE,  bottom=DBR_a[0], edgecolor='black')
ax1.bar(Ybar, DBR_a[2], bar_width1, color = C1_IT,  bottom=DBR_a[0]+DBR_a[1], edgecolor='black')
ax1.bar(Ybar, DBR_a[3], bar_width1, color = C1_SP,  bottom=DBR_a[0]+DBR_a[1]+DBR_a[2], edgecolor='black')
ax1.plot(Ybar, array(PUO_a[2]), color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax1.set_ylim(0,100)
ax1.text(1900, 22, r'English',fontsize=20)
ax1.set_xticks(arange(1900, 2010, 10) )
ax1.xaxis.set_tick_params(rotation=45)
ax1.set_ylabel(r' $NW$     ', rotation=90, fontsize = 23, fontweight = "bold")
ax1.set_xlabel(r'Years', fontsize=23)

ax2.bar(Ybar, DBR_b[0], bar_width1, color = C1_EN,  edgecolor='black')
ax2.bar(Ybar, DBR_b[1], bar_width1, color = C1_GE,  bottom=DBR_b[0], edgecolor='black')
ax2.bar(Ybar, DBR_b[2], bar_width1, color = C1_IT,  bottom=DBR_b[0]+DBR_b[1], edgecolor='black')
ax2.bar(Ybar, DBR_b[3], bar_width1, color = C1_SP,  bottom=DBR_b[0]+DBR_b[1]+DBR_b[2], edgecolor='black')
ax2.plot(Ybar, PUO_b[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax2.text(1900, 65, r'French',fontsize=20)
ax2.set_xticks(arange(1900, 2010, 10) )
ax2.xaxis.set_tick_params(rotation=45)
ax2.set_xlabel(r'Years', fontsize=23)

ax3.bar(Ybar, DBR_c[0], bar_width1, color = C1_EN,  edgecolor='black')
ax3.bar(Ybar, DBR_c[1], bar_width1, color = C1_FR,  bottom=DBR_c[0], edgecolor='black')
ax3.bar(Ybar, DBR_c[2], bar_width1, color = C1_IT,  bottom=DBR_c[0]+DBR_c[1], edgecolor='black')
ax3.bar(Ybar, DBR_c[3], bar_width1, color = C1_SP,  bottom=DBR_c[0]+DBR_c[1]+DBR_c[2], edgecolor='black')
ax3.plot(Ybar, PUO_c[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax3.text(1900, 75, r'German',fontsize=20)
ax3.set_xticks(arange(1900, 2010, 10) )
ax3.xaxis.set_tick_params(rotation=45)
ax3.set_xlabel(r'Years', fontsize=23)

ax4.bar(Ybar, DBR_d[0], bar_width1, color = C1_EN,  edgecolor='black')
ax4.bar(Ybar, DBR_d[1], bar_width1, color = C1_FR,  bottom=DBR_d[0], edgecolor='black')
ax4.bar(Ybar, DBR_d[2], bar_width1, color = C1_GE,  bottom=DBR_d[0]+DBR_d[1], edgecolor='black')
ax4.bar(Ybar, DBR_d[3], bar_width1, color = C1_SP,  bottom=DBR_d[0]+DBR_d[1]+DBR_d[2], edgecolor='black')[0]
ax4.plot(Ybar, PUO_d[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
#ax4.set_ylim(0,32)
ax4.text(1900, 32, r'Italian',fontsize=20)
ax4.set_xticks(arange(1900, 2010, 10) )
ax4.xaxis.set_tick_params(rotation=45)
ax4.set_ylabel(r' $NW$     ', rotation=90, fontsize = 23, fontweight = "bold")
ax4.set_xlabel(r'Years', fontsize=23)

ax5.bar(Ybar, DBR_e[0], bar_width1, color = C1_EN,  edgecolor='black')
ax5.bar(Ybar, DBR_e[1], bar_width1, color = C1_FR,  bottom=DBR_e[0], edgecolor='black')
ax5.bar(Ybar, DBR_e[2], bar_width1, color = C1_GE,  bottom=DBR_e[0]+DBR_e[1], edgecolor='black')
ax5.bar(Ybar, DBR_e[3], bar_width1, color = C1_IT,  bottom=DBR_e[0]+DBR_e[1]+DBR_e[2], edgecolor='black')
ax5.plot(Ybar, PUO_e[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax5.text(1900, 28, r'Spanish',fontsize=20)
ax5.set_xticks(arange(1900, 2010, 10) )
ax5.xaxis.set_tick_params(rotation=45)
ax5.set_xlabel(r'Years', fontsize=23)

color_labels = ['Source language', 'English', 'French', 'German', 'Italian', 'Spanish']
fig.legend([CEN, CFR, CGE, CIT, CSP, CIO],     # The line objects
           labels = color_labels,      # The labels for each line
           loc = 'best', 
           bbox_to_anchor =(0.35, 0.35, 0.1, 0.1),       # Position of legend
           borderaxespad = 0.1,     # Small spacing around legend box
           title="Legends"      # Title for the legend
           )

ax6.axis('off')




plt.tight_layout()
#fig.savefig('NW_A.png', bbox_inches = 'tight')
# Out:
# /home/josuely/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:1364: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   warnings.warn("You have mixed positional and keyword "
# /home/josuely/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:652: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
fig = plt.figure(figsize = [25,10])

ax1 = plt.subplot2grid(shape=(2,6), loc=(0,0))
ax2 = plt.subplot2grid(shape=(2,6), loc=(0,1))
ax3 = plt.subplot2grid(shape=(2,6), loc=(0,2))
ax4 = plt.subplot2grid(shape=(2,6), loc=(1,0))
ax5 = plt.subplot2grid(shape=(2,6), loc=(1,1))
ax6 = plt.subplot2grid(shape=(2,6), loc=(1,2))

ax1.bar(Ybar, (-1)*DBO_b[0], color = C1_EN, edgecolor='black')[0]
ax1.bar(Ybar, DBR_a[0], bar_width1, color = C1_FR,  edgecolor='black')
ax1.bar(Ybar, DBR_a[1], bar_width1, color = C1_GE,  bottom=DBR_a[0], edgecolor='black')
ax1.bar(Ybar, DBR_a[2], bar_width1, color = C1_IT,  bottom=DBR_a[0]+DBR_a[1], edgecolor='black')
ax1.bar(Ybar, DBR_a[3], bar_width1, color = C1_SP,  bottom=DBR_a[0]+DBR_a[1]+DBR_a[2], edgecolor='black')
ax1.plot(Ybar, array(PUO_a[2]), color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax1.set_ylim(0,100)
ax1.text(1900, 22, r'English',fontsize=20)
ax1.set_xticks(arange(1900, 2010, 10) )
ax1.xaxis.set_tick_params(rotation=25)
ax1.set_ylabel(r' $NW$     ', rotation=90, fontsize = 23, fontweight = "bold")
ax1.set_xlabel(r'Years', fontsize=23)

ax2.bar(Ybar, DBR_b[0], bar_width1, color = C1_EN,  edgecolor='black')
ax2.bar(Ybar, DBR_b[1], bar_width1, color = C1_GE,  bottom=DBR_b[0], edgecolor='black')
ax2.bar(Ybar, DBR_b[2], bar_width1, color = C1_IT,  bottom=DBR_b[0]+DBR_b[1], edgecolor='black')
ax2.bar(Ybar, DBR_b[3], bar_width1, color = C1_SP,  bottom=DBR_b[0]+DBR_b[1]+DBR_b[2], edgecolor='black')
ax2.plot(Ybar, PUO_b[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax2.text(1900, 65, r'French',fontsize=20)
ax2.set_xticks(arange(1900, 2010, 10) )
ax2.xaxis.set_tick_params(rotation=25)
ax2.set_xlabel(r'Years', fontsize=23)

ax3.bar(Ybar, DBR_c[0], bar_width1, color = C1_EN,  edgecolor='black')
ax3.bar(Ybar, DBR_c[1], bar_width1, color = C1_FR,  bottom=DBR_c[0], edgecolor='black')
ax3.bar(Ybar, DBR_c[2], bar_width1, color = C1_IT,  bottom=DBR_c[0]+DBR_c[1], edgecolor='black')
ax3.bar(Ybar, DBR_c[3], bar_width1, color = C1_SP,  bottom=DBR_c[0]+DBR_c[1]+DBR_c[2], edgecolor='black')
ax3.plot(Ybar, PUO_c[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax3.text(1900, 75, r'German',fontsize=20)
ax3.set_xticks(arange(1900, 2010, 10) )
ax3.xaxis.set_tick_params(rotation=25)
ax3.set_xlabel(r'Years', fontsize=23)

ax4.bar(Ybar, DBR_d[0], bar_width1, color = C1_EN,  edgecolor='black')
ax4.bar(Ybar, DBR_d[1], bar_width1, color = C1_FR,  bottom=DBR_d[0], edgecolor='black')
ax4.bar(Ybar, DBR_d[2], bar_width1, color = C1_GE,  bottom=DBR_d[0]+DBR_d[1], edgecolor='black')
ax4.bar(Ybar, DBR_d[3], bar_width1, color = C1_SP,  bottom=DBR_d[0]+DBR_d[1]+DBR_d[2], edgecolor='black')[0]
ax4.plot(Ybar, PUO_d[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
#ax4.set_ylim(0,32)
ax4.text(1900, 32, r'Italian',fontsize=20)
ax4.set_xticks(arange(1900, 2010, 10) )
ax4.xaxis.set_tick_params(rotation=25)
ax4.set_ylabel(r' $NW$     ', rotation=90, fontsize = 23, fontweight = "bold")
ax4.set_xlabel(r'Years', fontsize=23)

ax5.bar(Ybar, DBR_e[0], bar_width1, color = C1_EN,  edgecolor='black')
ax5.bar(Ybar, DBR_e[1], bar_width1, color = C1_FR,  bottom=DBR_e[0], edgecolor='black')
ax5.bar(Ybar, DBR_e[2], bar_width1, color = C1_GE,  bottom=DBR_e[0]+DBR_e[1], edgecolor='black')
ax5.bar(Ybar, DBR_e[3], bar_width1, color = C1_IT,  bottom=DBR_e[0]+DBR_e[1]+DBR_e[2], edgecolor='black')
ax5.plot(Ybar, PUO_e[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax5.text(1900, 28, r'Spanish',fontsize=20)
ax5.set_xticks(arange(1900, 2010, 10) )
ax5.xaxis.set_tick_params(rotation=25)
ax5.set_xlabel(r'Years', fontsize=23)

color_labels = ['Source language', 'English', 'French', 'German', 'Italian', 'Spanish']
fig.legend([CEN, CFR, CGE, CIT, CSP, CIO],     # The line objects
           labels = color_labels,      # The labels for each line
           loc='best', 
           bbox_to_anchor =(0.35, 0.35, 0.1, 0.1),       # Position of legend
           borderaxespad = 0.1,     # Small spacing around legend box
           title="Legends"      # Title for the legend
           )

ax6.axis('off')




plt.tight_layout()
#fig.savefig('NW_A.png', bbox_inches = 'tight')
# Out:
# /home/josuely/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:1364: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   warnings.warn("You have mixed positional and keyword "
# /home/josuely/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:652: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %%
fig = plt.figure(figsize = [19,15])
ax1_up = plt.subplot2grid(shape = (6,6), loc = (0,0), colspan=2, rowspan=1)
ax1_dn = plt.subplot2grid(shape = (6,6), loc = (1,0), colspan=2, rowspan=2)
ax2    = plt.subplot2grid(shape = (6,6), loc = (0,2), colspan=2, rowspan=3)
ax3    = plt.subplot2grid(shape = (6,6), loc = (0,4), colspan=2, rowspan=3)
ax4    = plt.subplot2grid(shape = (6,6), loc = (3,0), colspan=2, rowspan=3)
ax5    = plt.subplot2grid(shape = (6,6), loc = (3,2), colspan=2, rowspan=3)
ax6    = plt.subplot2grid(shape = (6,6), loc = (3,4), colspan=2, rowspan=3)

# ax1_up.spines['bottom'].set_visible(False)
# ax1_dn.spines['top'].set_visible(False)
# ax1_up.xaxis.tick_top()
# ax1_up.tick_params(labeltop=False) # don't put tick labels at the top
# ax1_dn.xaxis.tick_bottom()

# ax1_dn.bar(Ybar, (-1)*DBO_b[0], color = C1_EN, edgecolor='black')[0]
# ax1_dn.bar(Ybar, DBR_a[0], bar_width1, color = C1_FR,  edgecolor='black')
# ax1_dn.bar(Ybar, DBR_a[1], bar_width1, color = C1_GE,  bottom=DBR_a[0], edgecolor='black')
# ax1_dn.bar(Ybar, DBR_a[2], bar_width1, color = C1_IT,  bottom=DBR_a[0]+DBR_a[1], edgecolor='black')
# ax1_dn.bar(Ybar, DBR_a[3], bar_width1, color = C1_SP,  bottom=DBR_a[0]+DBR_a[1]+DBR_a[2], edgecolor='black')
# ax1_up.plot(Ybar, array(PUO_a[2]), color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
# ax1_up.set_ylim(34,102)
# ax1_dn.set_ylim(0,24)
# ax1_up.text(1900, 80, r'English',fontsize=20)
# ax1_dn.set_xticks(arange(1900, 2010, 10) )
# ax1_dn.xaxis.set_tick_params(rotation=25)
# ax1_dn.set_ylabel(r' $NMW$     ', rotation=90, fontsize = 23, fontweight = "bold")
# ax1_dn.set_xlabel(r'Years', fontsize=23)


ax2.bar(Ybar, DBR_b[0], bar_width1, color = C1_EN,  edgecolor='black')
ax2.bar(Ybar, DBR_b[1], bar_width1, color = C1_GE,  bottom=DBR_b[0], edgecolor='black')
ax2.bar(Ybar, DBR_b[2], bar_width1, color = C1_IT,  bottom=DBR_b[0]+DBR_b[1], edgecolor='black')
ax2.bar(Ybar, DBR_b[3], bar_width1, color = C1_SP,  bottom=DBR_b[0]+DBR_b[1]+DBR_b[2], edgecolor='black')
ax2.plot(Ybar, PUO_b[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax2.text(1900, 65, r'French',fontsize=20)
ax2.set_ylim(0,100)
ax2.set_xticks(arange(1900, 2010, 10) )
ax2.xaxis.set_tick_params(rotation=25)
ax2.set_xlabel(r'Years', fontsize=23)

ax3.bar(Ybar, DBR_c[0], bar_width1, color = C1_EN,  edgecolor='black')
ax3.bar(Ybar, DBR_c[1], bar_width1, color = C1_FR,  bottom=DBR_c[0], edgecolor='black')
ax3.bar(Ybar, DBR_c[2], bar_width1, color = C1_IT,  bottom=DBR_c[0]+DBR_c[1], edgecolor='black')
ax3.bar(Ybar, DBR_c[3], bar_width1, color = C1_SP,  bottom=DBR_c[0]+DBR_c[1]+DBR_c[2], edgecolor='black')
ax3.plot(Ybar, PUO_c[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax3.text(1900, 75, r'German',fontsize=20)
ax3.set_ylim(0,100)
ax3.set_xticks(arange(1900, 2010, 10) )
ax3.xaxis.set_tick_params(rotation=25)
ax3.set_xlabel(r'Years', fontsize=23)

ax4.bar(Ybar, DBR_d[0], bar_width1, color = C1_EN,  edgecolor='black')
ax4.bar(Ybar, DBR_d[1], bar_width1, color = C1_FR,  bottom=DBR_d[0], edgecolor='black')
ax4.bar(Ybar, DBR_d[2], bar_width1, color = C1_GE,  bottom=DBR_d[0]+DBR_d[1], edgecolor='black')
ax4.bar(Ybar, DBR_d[3], bar_width1, color = C1_SP,  bottom=DBR_d[0]+DBR_d[1]+DBR_d[2], edgecolor='black')[0]
ax4.plot(Ybar, PUO_d[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
#ax4.set_ylim(0,32)
ax4.text(1900, 32, r'Italian',fontsize=20)
ax4.set_ylim(0,100)
ax4.set_xticks(arange(1900, 2010, 10) )
ax4.xaxis.set_tick_params(rotation=25)
ax4.set_ylabel(r' $NMW$     ', rotation=90, fontsize = 23, fontweight = "bold")
ax4.set_xlabel(r'Years', fontsize=23)

ax5.bar(Ybar, DBR_e[0], bar_width1, color = C1_EN,  edgecolor='black')
ax5.bar(Ybar, DBR_e[1], bar_width1, color = C1_FR,  bottom=DBR_e[0], edgecolor='black')
ax5.bar(Ybar, DBR_e[2], bar_width1, color = C1_GE,  bottom=DBR_e[0]+DBR_e[1], edgecolor='black')
ax5.bar(Ybar, DBR_e[3], bar_width1, color = C1_IT,  bottom=DBR_e[0]+DBR_e[1]+DBR_e[2], edgecolor='black')
ax5.plot(Ybar, PUO_e[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ax5.text(1900, 28, r'Spanish',fontsize=20)
ax5.set_ylim(0,100)
ax5.set_xticks(arange(1900, 2010, 10) )
ax5.xaxis.set_tick_params(rotation=25)
ax5.set_xlabel(r'Years', fontsize=23)

ax6.axis('off')
color_labels = ['Source language', 'English', 'French', 'German', 'Italian', 'Spanish']
fig.legend([CEN, CFR, CGE, CIT, CSP, CIO],     # The line objects
           labels = color_labels,      # The labels for each line
           #loc='best', 
           bbox_to_anchor =(0.75, 0.35, 0.1, 0.1),       # Position of legend
           borderaxespad = 0.1,     # Small spacing around legend box
           title="Legends"      # Title for the legend
           )



plt.tight_layout()
#fig.savefig('NW_A.png', bbox_inches = 'tight')
# Out:
# /home/josuely/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:1364: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   warnings.warn("You have mixed positional and keyword "

# %%
fig = plt.figure(figsize = [19,15])

# ax1_up.spines['bottom'].set_visible(False)
# ax1_dn.spines['top'].set_visible(False)
# ax1_up.xaxis.tick_top()
# ax1_up.tick_params(labeltop=False) # don't put tick labels at the top
# ax1_dn.xaxis.tick_bottom()
subplot(2,3,1)
bar(Ybar, (-1)*DBO_b[0], color = C1_EN, edgecolor='black')[0]
bar(Ybar, DBR_a[0], bar_width1, color = C1_FR,  edgecolor='black')
bar(Ybar, DBR_a[1], bar_width1, color = C1_GE,  bottom=DBR_a[0], edgecolor='black')
bar(Ybar, DBR_a[2], bar_width1, color = C1_IT,  bottom=DBR_a[0]+DBR_a[1], edgecolor='black')
bar(Ybar, DBR_a[3], bar_width1, color = C1_SP,  bottom=DBR_a[0]+DBR_a[1]+DBR_a[2], edgecolor='black')
plot(Ybar, array(PUO_a[2]), color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
ylim(0,100)
text(1900, 80, r'English',fontsize=20)
xticks(arange(1900, 2010, 10), rotation=25 )
#xaxis.set_tick_params(rotation=25)
ylabel(r' $NMW$     ', rotation=90, fontsize = 23, fontweight = "bold")
xlabel(r'Years', fontsize=23)

subplot(2,3,2)
bar(Ybar, DBR_b[0], bar_width1, color = C1_EN,  edgecolor='black')
bar(Ybar, DBR_b[1], bar_width1, color = C1_GE,  bottom=DBR_b[0], edgecolor='black')
bar(Ybar, DBR_b[2], bar_width1, color = C1_IT,  bottom=DBR_b[0]+DBR_b[1], edgecolor='black')
bar(Ybar, DBR_b[3], bar_width1, color = C1_SP,  bottom=DBR_b[0]+DBR_b[1]+DBR_b[2], edgecolor='black')
plot(Ybar, PUO_b[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
text(1900, 80, r'French',fontsize=20)
ylim(0,100)
xticks(arange(1900, 2010, 10), rotation=25)
#xaxis.set_tick_params(rotation=25)
xlabel(r'Years', fontsize=23)

subplot(2,3,3)
bar(Ybar, DBR_c[0], bar_width1, color = C1_EN,  edgecolor='black')
bar(Ybar, DBR_c[1], bar_width1, color = C1_FR,  bottom=DBR_c[0], edgecolor='black')
bar(Ybar, DBR_c[2], bar_width1, color = C1_IT,  bottom=DBR_c[0]+DBR_c[1], edgecolor='black')
bar(Ybar, DBR_c[3], bar_width1, color = C1_SP,  bottom=DBR_c[0]+DBR_c[1]+DBR_c[2], edgecolor='black')
plot(Ybar, PUO_c[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
text(1900, 80, r'German',fontsize=20)
ylim(0,100)
xticks(arange(1900, 2010, 10), rotation=25 )
#xaxis.set_tick_params(rotation=25)
xlabel(r'Years', fontsize=23)

subplot(2,3,4)
bar(Ybar, DBR_d[0], bar_width1, color = C1_EN,  edgecolor='black')
bar(Ybar, DBR_d[1], bar_width1, color = C1_FR,  bottom=DBR_d[0], edgecolor='black')
bar(Ybar, DBR_d[2], bar_width1, color = C1_GE,  bottom=DBR_d[0]+DBR_d[1], edgecolor='black')
bar(Ybar, DBR_d[3], bar_width1, color = C1_SP,  bottom=DBR_d[0]+DBR_d[1]+DBR_d[2], edgecolor='black')[0]
plot(Ybar, PUO_d[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
text(1900, 80, r'Italian',fontsize=20)
ylim(0,100)
xticks(arange(1900, 2010, 10),rotation =25 )
#xaxis.set_tick_params(rotation=25)
ylabel(r' $NMW$     ', rotation=90, fontsize = 23, fontweight = "bold")
xlabel(r'Years', fontsize=23)

subplot(2,3,5)
bar(Ybar, DBR_e[0], bar_width1, color = C1_EN,  edgecolor='black')
bar(Ybar, DBR_e[1], bar_width1, color = C1_FR,  bottom=DBR_e[0], edgecolor='black')
bar(Ybar, DBR_e[2], bar_width1, color = C1_GE,  bottom=DBR_e[0]+DBR_e[1], edgecolor='black')
bar(Ybar, DBR_e[3], bar_width1, color = C1_IT,  bottom=DBR_e[0]+DBR_e[1]+DBR_e[2], edgecolor='black')
plot(Ybar, PUO_e[2], color = 'black', marker='o', linestyle='--', linewidth=3.5, markersize=12)
text(1900, 80, r'Spanish',fontsize=20)
ylim(0,100)
xticks(arange(1900, 2010, 10), rotation=25 )
#xaxis.set_tick_params(rotation=25)
xlabel(r'Years', fontsize=23)

subplot(2,3,6)
axis('off')
color_labels = ['Source language', 'English', 'French', 'German', 'Italian', 'Spanish']
fig.legend([CEN, CFR, CGE, CIT, CSP, CIO],     # The line objects
           labels = color_labels,      # The labels for each line
           #loc='best', 
           bbox_to_anchor =(0.75, 0.35, 0.1, 0.1),       # Position of legend
           borderaxespad = 0.1,     # Small spacing around legend box
           title="Legends"      # Title for the legend
           )



plt.tight_layout()
fig.savefig('NW_A_ejes.png', bbox_inches = 'tight')
# Out:
# /home/josuely/anaconda3/lib/python3.6/site-packages/matplotlib/legend.py:1364: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   warnings.warn("You have mixed positional and keyword "
